# %%
#Feature Engineering and Data Preprocessing(Machine Learning)

#Remove User ID
import pandas as pd

df = pd.read_csv("../data/phone_usage_india.csv")

df = df.drop(columns=["User ID"])
#print(df.head())

# %%
#Features
X = df.drop("Primary Use", axis=1)
#print(x.head())
#print(df.head())

#Target
y = df["Primary Use"]

print("X Shape:",X.shape)
print("Y Shape:",y.shape)

print("\nFeatures:",X.columns.tolist())
print("\nTarget:",y.name)
# Out:
# X Shape: (17686, 14)
# Y Shape: (17686,)
#
# Features: ['Age', 'Gender', 'Location', 'Phone Brand', 'OS', 'Screen Time (hrs/day)', 'Data Usage (GB/month)', 'Calls Duration (mins/day)', 'Number of Apps Installed', 'Social Media Time (hrs/day)', 'E-commerce Spend (INR/month)', 'Streaming Time (hrs/day)', 'Gaming Time (hrs/day)', 'Monthly Recharge Cost (INR)']
#
# Target: Primary Use

# %%
#Categorical Encoding
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Encode Primary Use Variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

#Encode Feature Columns
X = pd.get_dummies(
    X,
    columns = ["Gender", "Location", "Phone Brand", "OS"],
    drop_first=True
)

print("\n Encoded Features:", X.shape)
print("\n First 5 rows:", X.head())
print("\n Encoded Target Classes", label_encoder.classes_)
# Out:
#  Encoded Features: (17686, 31)
#
#  First 5 rows:    Age  Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0   53                    3.7                   23.9
# 1   60                    9.2                   28.1
# 2   37                    4.5                   12.3
# 3   32                   11.0                   25.6
# 4   16                    2.2                    2.5
#
#    Calls Duration (mins/day)  Number of Apps Installed  \
# 0                       37.9                       104
# 1                       13.7                       169
# 2                       66.8                        96
# 3                      156.2                       146
# 4                      236.2                        86
#
#    Social Media Time (hrs/day)  E-commerce Spend (INR/month)  \
# 0                          3.9                           469
# 1                          2.8                          4997
# 2                          3.0                          2381
# 3                          5.2                          1185
# 4                          5.5                           106
#
#    Streaming Time (hrs/day)  Gaming Time (hrs/day)  \
# 0                       5.2                    4.1
# 1                       5.1                    0.4
# 2                       1.7                    2.9
# 3                       3.2                    0.3
# 4                       3.4                    2.3
#
#    Monthly Recharge Cost (INR)  ...  Phone Brand_Google Pixel  \
# 0                          803  ...                     False
# 1                         1526  ...                     False
# 2                         1619  ...                     False
# 3                         1560  ...                     False
# 4                          742  ...                     False
#
#    Phone Brand_Motorola  Phone Brand_Nokia  Phone Brand_OnePlus  \
# 0                 False              False                False
# 1                 False              False                False
# 2                 False               True                False
# 3                 False              False                False
# 4                 False              False                False
#
#    Phone Brand_Oppo  Phone Brand_Realme  Phone Brand_Samsung  \
# 0             False               False                False
# 1             False                True                False
# 2             False               False                False
# 3             False               False                 True
# 4             False               False                False
#
#    Phone Brand_Vivo  Phone Brand_Xiaomi  OS_iOS
# 0              True               False   False
# 1             False               False    True
# 2             False               False   False
# 3             False               False   False
# 4             False                True    True
#
# [5 rows x 31 columns]
#
#  Encoded Target Classes ['Education' 'Entertainment' 'Gaming' 'Social Media' 'Work']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42 
)

print("Training Faetures Shape:", x_train.shape)
print("Testing Features Shape:", x_test.shape)

print("Training Target Shape:", y_train.shape)
print("Testing Target Shape:", y_test.shape)
# Out:
# Training Faetures Shape: (14148, 31)
# Testing Features Shape: (3538, 31)
# Training Target Shape: (14148,)
# Testing Target Shape: (3538,)
